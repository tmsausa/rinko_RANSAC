# %% [markdown]
# # Hands-on Lecture 1
# ## Implementation of RANSAC
#
# RANSAC (RANdom SAmple Consensus) は外れ値に頑健な線形回帰の一手法です。外れ値の検出にも用いることができます。
#
# RANSACはインスタンス認識において2枚の画像に写る物体の対応をとるアフィン変換を求める時など、コンピュータビジョンの分野においてよく利用されます。
# <img src="figure/before.png" left style="width: 450px;"  >
# <center>Raw keypoint matching result</center>
# <img src="figure/after.png" style="width: 450px;">
# <center>After removing outliers</center>
#
#
#
#
# - このノートブックではRANSACを実装し、2D画像におけるアフィン変換を求めます。
#
# - RANSACにおける入力と出力は以下のようになります:
#
# **Input**:
# $$
# D = \{(\boldsymbol{x}_1, \boldsymbol{x}'_1), \cdots ,(\boldsymbol{x}_N, \boldsymbol{x}'_N) \}\\
# \boldsymbol{x}_i = (x_i, y_i) \in \mathbb{Z}^2
# $$
#
#
#
# **Output**:
# $$
# H = \begin{pmatrix}
# A & \boldsymbol{t} \\
# \boldsymbol{0}^{\mathrm T} & 1\\
# \end{pmatrix}
# $$
# where,
# $$
# A \in \mathbb{R}^{2 \times 2},\\
# \boldsymbol{t} \in \mathbb{R}^{2 \times 1},\\
# \boldsymbol{0}^{\mathrm T} = (0, 0) \in \mathbb{R}^{1 \times 2}
# $$
#
# $(\boldsymbol{x}_i, \boldsymbol{x}'_i)$ は${\boldsymbol i}$番目の座標ペアです。また、アフィン変換行列$H$は次のような線形変換$A$と移動$\boldsymbol{t}$が含まれます。
# $$
# (\boldsymbol{x}'_i, 1)^{\mathrm T} = \begin{pmatrix}
# A & \boldsymbol{t} \\
# \boldsymbol{0}^{\mathrm T} & 1\\
# \end{pmatrix}
# (\boldsymbol{x}_i, 1)^{\mathrm T}
# = H (\boldsymbol{x}_i, 1)^{\mathrm T}
# $$
#
#
# - RANSACのアルゴリズムを分解し、それぞれを実装していきましょう。

# %% [markdown]
# ### 0. ライブラリのインポート

# %%
import numpy as np
import cv2
from PIL import Image
from random import choice
from scipy import hypot
from scipy.linalg import inv

import matplotlib.pyplot as plt
 

# from sift import match, read_features_from_file, plot_matches, plot_features
# from ransac import get_points, get_homography

from utili import *

import os
from scipy import *
from numpy import *
from scipy.ndimage import *

# %matplotlib inline
print("cv2.version: " , cv2.__version__)
# Out:
# cv2.version:  3.4.1

# %% [markdown]
# ###  今回用いる画像の読み込み

# %%
# load images
img_box = np.asarray(Image.open('figure/box.pgm').convert('L'))
img_scene = np.asarray(Image.open('figure/scene.pgm').convert('L'))
 
# Show images

plt.imshow(img_box, cmap='gray')
plt.show()
plt.imshow(img_scene, cmap='gray')
plt.show()

# %% [markdown]
# ### SIFTキーポイントの検出とSIFT特徴の計算

# %%
#init SIFT detector
sift_detector = cv2.xfeatures2d.SIFT_create()

#detect kpoints and compute decriptions
kp_scene, des_scene = sift_detector.detectAndCompute(img_scene,None)
kp_box, des_box = sift_detector.detectAndCompute(img_box,None)


#show detection result
detection_box   = cv2.drawKeypoints(img_box, kp_box, None)
detection_scene = cv2.drawKeypoints(img_scene, kp_scene, None)
plt.imshow(detection_box)
plt.show()
plt.imshow(detection_scene)
plt.show()

# %% [markdown]
# ### 2枚の画像におけるマッチングの計算

# %%
# brute force matching
bf = cv2.BFMatcher()
matches = bf.match(des_box, des_scene)
matches = sorted(matches, key = lambda x:x.distance)[:150]
matching_result = cv2.drawMatches(img_box, kp_box, img_scene, kp_scene, matches, None, flags=2)

#draw matchings 
fig, ax = plt.subplots(figsize=(12, 20))
ax.imshow(matching_result)
plt.show()

# %% [markdown]
# ### マッチングの結果を取得
# $$
# points\_list = \{(\boldsymbol{x}_1, \boldsymbol{x}'_1), \cdots ,(\boldsymbol{x}_N, \boldsymbol{x}'_N) \}\\
# \boldsymbol{x}_i = (x_i, y_i) \in \mathbb{Z}^2
# $$

# %%
points_list = get_points(matches , kp_box,  kp_scene)

# %% [markdown]
# ### 1. points_listから要素をランダムに取得
# - まず最初に、points_listから3つのマッチングをランダムに選ぶ関数の実装をします。
# - **```choice```** 関数を使うことで、リストからランダムに要素を選ぶことができます。

# %%
# set the seed 0
np.random.seed(0)

# %%
def select_three_samples(points_list):
    """
    Select 3 samples from points_list.
    
    Parameters
    ----------
    points_list: numpy array of feature pairs D = {(x_i, x'_i)}_{i=1}^N
    
    
    returns
    -------
    consensus_list: 3 samples randomly chosen from point_list
    points_list_temp: all the feature pairs other than the samples in consensus_list
    """
    
    points_list_temp = np.copy(points_list).tolist()
    consensus_list = []

    #### START HERE ####
    for _ in range(3):
        selected_sample = None
        consensus_list.hoge
        points_list_temp.hoge
    #### END HERE ####
    
    return consensus_list, points_list_temp

# %%
# get random pairs
consensus_list, points_list_temp=select_three_samples(points_list)
temp_im = plot_points_list( img_box, img_scene, consensus_list)


#draw 3 matches
fig, ax = plt.subplots(figsize=(12, 20))
ax.imshow(temp_im)
plt.show()

# %% [markdown]
# ### 2. 選ばれた3つの要素からアフィン変換の計算
# - 1では3つランダムに要素を取得しました。
# - 次にこれらの要素を使ってアフィン変換を計算します。

# %%
def affine_from_points(consensus_list):
    """
    Calculate affine transformation matrix H from consensus_list.
    
    Parameters
    ----------
    consensus_list: 3 samples chosen randomly.
    
    Returns
    -------
    H: the affine transformation.
    """
    
    # devide consensus_list and add the bias term
    fp = np.array([coordinate[0] + [1] for coordinate in consensus_list]).T
    tp = np.array([coordinate[1] + [1] for coordinate in consensus_list]).T
    if fp.shape != tp.shape:
        raise RuntimeError

    #condition points
    #-from points-
    m = np.mean(fp[:2], axis=1)
    maxstd = np.max(np.std(fp[:2], axis=1))
    C1 = np.diag([1/maxstd, 1/maxstd, 1])
    C1[0][2] = -m[0]/maxstd
    C1[1][2] = -m[1]/maxstd
    fp_cond = np.dot(C1,fp)

    #-to points-
    m = np.mean(tp[:2], axis=1)
    C2 = C1.copy() #must use same scaling for both point sets
    C2[0][2] = -m[0]/maxstd
    C2[1][2] = -m[1]/maxstd
    tp_cond = np.dot(C2,tp)

    #conditioned points have mean zero, so translation is zero
    A = np.concatenate((fp_cond[:2], tp_cond[:2]), axis=0)
    U,S,V = np.linalg.svd(A.T)

    #create B and C matrices as Hartley-Zisserman (2:nd ed) p 130.
    tmp = V[:2].T
    B = tmp[:2]
    C = tmp[2:4]

    tmp2 = np.concatenate((np.dot(C, np.linalg.pinv(B)), np.zeros((2,1))), axis=1)
    H = np.vstack((tmp2, [0,0,1]))

    #decondition
    H = np.dot(np.linalg.inv(C2), np.dot(H, C1))

    return H / H[2][2]
    
    return H

# %% [markdown]
# ### 結果の図示

# %%
#Select 3 samples randomly and draw them
consensus_list, points_list_temp=select_three_samples(points_list)
temp_im=plot_points_list( img_box, img_scene, consensus_list)

plt.figure(figsize=(8,8))
plt.imshow(temp_im)
plt.show()

#calculate affine transform from the 3 pairs
temp_H = affine_from_points(consensus_list) 


# show affine transformation result. 
# try to run this cell multiple times, and see how the image changes different matchings
dst = cv2.warpAffine(img_box, temp_H[0:2 , :] , (img_scene.shape[1],img_scene.shape[0]))
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.imshow(dst,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(img_scene,cmap='gray')
plt.show()

# %% [markdown]
# ### 3. アフィン変換に矛盾しない要素の取得
# - これまでの実装で、ランダムに選んだ3つの要素からアフィン変換を計算することができました。
# - 次に、他の要素について、求めた$H$と矛盾しないものを探します。
# - 矛盾しないとは、適当な閾値$\theta$を設定することで, 次の値が$\theta$以下の要素であるということと定義します。
# $$d({\boldsymbol x}', H{\boldsymbol x}) = \sqrt{(\boldsymbol{x}' - H\boldsymbol{x})^T(\boldsymbol{x}' - H\boldsymbol{x})}$$
# - $H$と矛盾しない要素を**```consensus_set```** に追加しましょう。
# - **```np.hypot```** 関数を用いて2つの点のl2距離を計算することができます。

# %%
def select_samples_within_threshold(points_list_temp, consensus_list,\
                                    H, theta=10):
    """
    Select the sapmles whose error from the projection by H is less than theta.
    
    Parameters
    ----------
    point_list_temp: list of all the points except for the 3 points selected before.
    consensus_list: the 3 points.
    H: the affine transformation.
    theta: threshold value.
    
    Returns
    -------
    updated_consensus_list: list of all the points whose error from the projection by H is within theta.
    """
    
    updated_consensus_list = consensus_list[:]
    for p in points_list_temp:
        x1, y1 = p[0]
        x2, y2 = p[1]
        
        # reshape and add the bias term
        A = np.array([x1, y1, 1]).reshape(3,1)
        B = np.array([x2, y2, 1]).reshape(3,1)
        
        #### START HERE ####
        out = None # calculate the difference between B and HA
        dist_err = None # calculate the distance 
        #### END HERE ####
        
        try:
            if dist_err < theta:
                updated_consensus_list.append(p) # add this sample into consensus_set
        except ValueError:
            print(dist_err)
            print(type(dist_err))
            print(dist_err.shape)
    return updated_consensus_list

# %%
#Select 3 samples randomly and draw them
consensus_list, points_list_temp=select_three_samples(points_list)
temp_im=plot_points_list( img_box, img_scene, consensus_list)
print("sampled pairs")
plt.figure(figsize=(8,8))
plt.imshow(temp_im)
plt.show()

#calculate affine transform from the 3 pairs
temp_H =  affine_from_points( consensus_list ) 


# Get all all pairs that do not contradit to temp_H . 
# run this cell multiple time and see which affine transformation get the most supporters
supporter_list = select_samples_within_threshold( points_list  , consensus_list , temp_H )
print("There are" ,len(supporter_list) , " pairs that do not contradict to the affine transformation, they are:")
#Display the supporter list
temp_im=plot_points_list( img_box, img_scene, supporter_list)
plt.figure(figsize=(8,8))
plt.imshow(temp_im)
plt.show()

# show affine transformation result. 
# try to run this cell multiple times, and see how the image changes different matchings
dst = cv2.warpAffine(img_box, temp_H[0:2 , :] , (img_scene.shape[1],img_scene.shape[0]))
plt.figure(figsize=(6,6))
plt.subplot(1,2,1)
plt.imshow(dst,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(img_scene,cmap='gray')
plt.show()
# Out:
# sampled pairs
# There are 7  pairs that do not contradict to the affine transformation, they are:

# %% [markdown]
# ### 4. アフィン変換の再計算
# - 3より```updated_consensus_list```を得ることができました。これには$H$に矛盾しない```points_list```の要素が含まれます。
# - $N_{tmp} > N_{max}$ の時に$H$を再計算します。ここで、
#     - $N_{tmp}$は現在の```consensus_list```の要素数を表します。
#     - $N_{max}$はこれまでの$N_{tmp}$の最大値を表します。
# - セクション2の**```affine_from_points```** を用いてアフィン変換を計算することができます。

# %%
def recalculate_affine_transformation(updated_consensus_list, N_max, H_best):
    """
    Recalculate the affine transformation if N_tmp > N_max
    
    Parameters
    ----------
    updated_consensus_list: 
    N_max: 
    H_best: 
    Returns
    -------
    H_best: affine transformation.
    N_max: N_max
    """
    
    N_tmp = len(updated_consensus_list)
    if N_tmp > N_max:
        #### START HERE ####
        H_best = None
        N_max = None
        #### END HERE ####
    return H_best, N_max

# %% [markdown]
# ### 5. 統合
# - これまででRANSACに必要な関数を実装しました。
# - 次にこれらを統合し、RANSACを完成させます。

# %%
def RANSAC(points_list, M=20, theta=5.):
    """
    Calculate affine transformation using RANSAC.
    
    Parameters
    ----------
    points_list: list of points = [[[x_1, y_1], [x'_1, y'_1]], ...].
    M: number of iterations.
    theta: threshold.
    
    Returns
    -------
    H_best: the best affine transformation.
    """
    # initialize N_max := 0, H_best := np.eye(3)
    N_max = 0    
    H_best = np.eye(3)
    # iterate M times
    for i in range(M):
        
        #### START HERE ####
        # 1. select 3 points randomly
        consensus_list, points_list_temp = None
        
        # 2. Calculate affine transformation from these 3 samples
        H = None
        
        # 3. Select points which do not contradict the affine transformation
        updated_consensus_list = None
        
        # 4. Recalculate affine transformation matrix by updated_consensus_list
        H_best, N_max = None
        
        #### END HERE ####
    return H_best

# %%
temp_H=RANSAC(points_list)

# show affine transformation result. 
# try to run this cell multiple times, and see how the image changes different matchings
dst = cv2.warpAffine(img_box, temp_H[0:2 , :] , (img_scene.shape[1],img_scene.shape[0]))
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.imshow(dst,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(img_scene,cmap='gray')
plt.show()

# Get all all pairs that do not contradit to temp_H . 
# run this cell multiple time and see which affine transformation get the most supporters
supporter_list = select_samples_within_threshold( points_list  , consensus_list , temp_H )
print("There are" ,len(supporter_list) , " pairs that do not contradict to the affine transformation, they are:")
#Display the supporter list
temp_im=plot_points_list( img_box, img_scene, supporter_list)
plt.figure(figsize=(8,8))
plt.imshow(temp_im)
plt.show()
# Out:
# There are 87  pairs that do not contradict to the affine transformation, they are:

# %% [markdown]
# ### お疲れ様でした。このノートブックの演習は以上です。

# %% [markdown]
# ## 出典
# - https://github.com/vishwa91/pyimreg
# - http://www.cs.ubc.ca/~lowe/keypoints/
